# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rc('font', family = "batang")
plt.rc('axes', unicode_minus = False)

# %%
plt.plot([1, 2, 3, 4])
plt.title("한글")
plt.show()

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
print(titanic.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB
# None

# %%
## missing
print("missing value = ")
print(titanic.isnull().sum())

titanic = titanic_df.loc[:, :"fare"]
titanic.info()

titanic.dropna(axis = 0, inplace=True)
# Out:
# missing value =
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Index: 714 entries, 0 to 890
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  714 non-null    int64
#  1   pclass    714 non-null    int64
#  2   sex       714 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     714 non-null    int64
#  5   parch     714 non-null    int64
#  6   fare      714 non-null    float64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 44.6+ KB

# %%
titanic_df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare
# 0         0       3    male  22.0      1      0   7.2500
# 1         1       1  female  38.0      1      0  71.2833
# 2         1       3  female  26.0      0      0   7.9250
# 3         1       1  female  35.0      1      0  53.1000
# 4         0       3    male  35.0      0      0   8.0500

# %%
## sns.regplot (연속형변수 - 이자료에선 age, fare 밖에없쥐)
fig, ax = plt.subplots()
sns.regplot(titanic_df, x = "age", y = "fare")
plt.show()
fig.savefig("titanic_reg.png") #사진이 저장됨.

# %%
sns.regplot(titanic_df,
            x="age", y="fare",
            fit_reg=True,
            color="hotpink",
            marker="o",
            order=2, #order: 1차, 2차,, n차 
            scatter_kws={"fc":"hotpink", "ec":"hotpink", "s":100, "alpha":0.3}, #alpha투명도
            label="Titanic data",
            line_kws = {"lw":4, "ls": "--", "alpha": 0.8})
plt.title("나이 vs 요금")
plt.xlabel("나이")
plt.ylabel("요금")
plt.legend(loc=0)
plt.show()

# %%
## Axis level plot - 종이 하나일 때 
diamonds = sns.load_dataset("diamonds")
diamonds.head()

#cut = ideal => price vs carat (replot)

diamonds_df = diamonds[diamonds["cut"] == "Ideal"]
diamonds_df.shape
#딕셔너리 형태로 넣으세용 
sns.regplot(diamonds_df.sample(n = 1000),
            x="carat", y="price",
            scatter_kws={"fc":"hotpink", "ec":"hotpink", "s":100, "alpha":0.5},
            line_kws = {"color":"r"},
            order =2
            )
plt.title("Carat vs Price")
plt.xlabel("Carat")
plt.ylabel("Price")
plt.show()

sns.lmplot(diamonds.sample(n=5000),
            x = "carat",
            y = "price",
            col = "clarity",
            col_wrap = 4,                       
            hue = "cut")
p.set_titles(size = 15) #subplot 의 제목 
p.set_xlabels("Carat", size = 15)
p.set_ylabels("Price", size = 15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 27
#      19 plt.show()
#      21 sns.lmplot(diamonds.sample(n=5000),
#      22             x = "carat",
#      23             y = "price",
#      24             col = "clarity",
#      25             col_wrap = 4,
#      26             hue = "cut")
# ---> 27 p.set_titles(size = 15)
#      28 p.set_xlabels("Carat", size = 15)
#      29 p.set_ylabels("Price", size = 15)
#
# NameError: name 'p' is not defined

# %%
## Figure level plot
# sns.lmplot (linear) #종을 구분하여 그릴 때는 lmplot 이 훨씬좋다 
penguins = sns.load_dataset("penguins")
print(penguins.head())
print(penguins["species"].value_counts())
print(penguins.info())
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
# ...

# %%
sns.lmplot(penguins, 
            x = "bill_length_mm",
            y = "bill_depth_mm",
            hue = "species",
            col = "sex")

plt.show()

# %%
sns.lmplot(penguins, 
            x = "bill_length_mm",
            y = "bill_depth_mm",
            col = "species",
            row = "sex",
            hue = "island",
            sharex = False,
            sharey = False)
plt.show()
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\regression.py:598: UserWarning: sharex is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\regression.py:598: UserWarning: sharey is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)

# %%
## sns.scatterplot
tips = sns.load_dataset("tips")
print("tips = \n", tips.head(), "\n")
print("="*50)
print(tips.info())
# Out:
# tips =
#     total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
#
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
# None

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.scatterplot(tips,
                x = "total_bill",
                y = "tip",
                hue = "time",
                #style = "sex",
                s = 100,
                alpha = 0.7,
                palette=("Set2"))
plt.show()

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
diamonds.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
#여러개의 종류중에 몇 개만 지정해서 보고싶을 때는 인덱스 지정 

color_idx = (diamonds["color"] == "D") | (diamonds["color"] == "E") | (diamonds["color"] == "F")
cut_idx = (diamonds["cut"] == "Ideal") | (diamonds["cut"] == "Good") | (diamonds["cut"] == "Fair")
final_idx = color_idx & cut_idx
print(final_idx)

diamonds_df  = diamonds[final_idx]
diamonds_df["color"] = diamonds_df["color"].cat.remove_unused_categories()
diamonds_df["cut"] = diamonds_df["cut"].cat.remove_unused_categories()
diamonds_df.shape

fig, ax = plt.subplots(figsize = (6, 6))
sns.scatterplot(diamonds_df.sample(n=1000),
                x = "carat",
                y = "price",
                hue = "color",
                style = "cut",
                s = 100,
                palette=("Set2"))
plt.title("Diamonds Data")
plt.show()
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 20250    False
# 20251    False
# 20252    False
# 20253    False
# 20254    False
# Length: 20255, dtype: bool
# C:\Users\user\AppData\Local\Temp\ipykernel_9524\780724061.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamonds_df["color"] = diamonds_df["color"].cat.remove_unused_categories()
# C:\Users\user\AppData\Local\Temp\ipykernel_9524\780724061.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
import seaborn as sns

# Seaborn의 내장 데이터셋 이름을 가져오는 함수 호출
dataset_names = sns.get_dataset_names()

# 데이터셋 이름 출력
print(dataset_names)
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
healthexp = sns.load_dataset("healthexp")
print(healthexp.head())
print(healthexp.info)
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9
# <bound method DataFrame.info of      Year        Country  Spending_USD  Life_Expectancy
# 0    1970        Germany       252.311             70.6
# 1    1970         France       192.143             72.2
# 2    1970  Great Britain       123.993             71.9
# 3    1970          Japan       150.437             72.0
# 4    1970            USA       326.961             70.9
# ..    ...            ...           ...              ...
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# ...

# %%
## 이산형 데이터에 대한 연속형 data 
penguins = sns.load_dataset("penguins")
penguins.head()

fig, axs = plt.subplots(1,2, figsize = (8, 4))
sns.barplot(penguins,
            x = "species",
            y = "body_mass_g",
            alpha = 0.6,
            errorbar = "sd",
            hue = "sex",
            palette=("Set2"),
            estimator = "mean", ax = axs[0])
axs[0].set_title("Mean")
sns.barplot(penguins,
            x = "species",
            y = "body_mass_g",
            hue = "sex",
            alpha = 0.6,
            errorbar = "sd",
            palette=("Set3"),
            estimator = "median", ax = axs[1])
axs[1].set_title("Median")
plt.subplots_adjust(wspace = 0.8)
plt.show()

# %%
fmri.columns
# Out:
# Index(['subject', 'timepoint', 'event', 'region', 'signal'], dtype='object')

# %%
iris = sns.load_dataset("iris")
iris.head()
y_list = iris.columns[:4]

fig, axes = plt.subplots(1,4, figsize = (8, 4))
for i in range(4):
    sns.barplot(iris, x = "species", y = y_list[i], hue = "species", ax = axes[i])
sns.barplot(iris,
            x = "species",
            y = "sepal_length",
            hue = "species",
            ax = axes[0],
            palette=("Set2"))
sns.barplot(iris,
            x = "species",
            y = "sepal_width",
            hue = "species",
            ax = axes[1],
            palette=("Set1"))
sns.barplot(iris,
            x = "species",
            y = "petal_length",
            hue = "species",
            ax = axes[2],
            palette=("Set3"))
sns.barplot(iris,
            x = "species",
            y = "petal_width",
            hue = "species",
            ax = axes[3],
            palette=("Set1"))


plt.subplots_adjust(wspace = 0.8)
plt.show()

# %%
mpg = sns.load_dataset("mpg")
mpg_df = pd.DataFrame(mpg)
print(mpg.columns)
# print(mpg_df.head())
#print(mpg.info())
print("Value counts of cyl, origin = \n", mpg_df[["cylinders", "origin"]].value_counts())
mean_std_df = mpg.groupby('cylinders').agg(
    mean=('mpg', 'mean'),
    std=('mpg', 'std')
).reset_index()
mean_std_df.set_index('cylinders', inplace=True)
print(mean_std_df)

print("max&weight = \n", mpg[['mpg', 'weight']].max())
print('*'*50)

mpg_wt_df = mpg[['mpg', 'weight']]
increase_factors = [0.25, 0.50, 0.75, 1.00]

print(mpg_df[["mpg", "weight"]].quantile(0.25))

print("mpg를 프린트해바 \n", mpg)
print("❤️mpg =", mpg.loc[:, "mpg"])
add_kpg = mpg["mpg"]*1.61
mpg.insert(1, "kpg", add_kpg)
print(mpg)

sns.barplot(mpg_df,
            x = "cylinders",
            y = "horsepower",
            palette=("Set2"))
plt.show()
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')
# Value counts of cyl, origin =
#  cylinders  origin
# 8          usa       103
# 6          usa        74
# 4          usa        72
#            japan      69
#            europe     63
# 6          japan       6
# 3          japan       4
# 6          europe      4
# 5          europe      3
# Name: count, dtype: int64
#                 mean       std
# cylinders
# 3          20.550000  2.564501
# 4          29.286765  5.710156
# 5          27.366667  8.228204
# 6          19.985714  3.807322
# 8          14.963107  2.836284
# max&weight =
#  mpg         46.6
# weight    5140.0
# dtype: float64
# **************************************************
# mpg         17.50
# weight    2223.75
# Name: 0.25, dtype: float64
# mpg를 프린트해바
#        mpg  cylinders  displacement  horsepower  weight  acceleration  \
# ...
